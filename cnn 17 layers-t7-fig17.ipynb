# %%
pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.19.0-cp310-cp310-win_amd64.whl (375.7 MB)
#      -------------------------------------- 375.7/375.7 MB 7.7 MB/s eta 0:00:00
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.71.0-cp310-cp310-win_amd64.whl (4.3 MB)
#      ---------------------------------------- 4.3/4.3 MB 21.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging in c:\users\punna\appdata\roaming\python\python310\site-packages (from tensorflow) (24.2)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\punna\appdata\roaming\python\python310\site-packages (from tensorflow) (4.13.2)
# Collecting wrapt>=1.11.0
#   Downloading wrapt-1.17.2-cp310-cp310-win_amd64.whl (38 kB)
# Collecting keras>=3.5.0
#   Downloading keras-3.9.2-py3-none-any.whl (1.3 MB)
#      ---------------------------------------- 1.3/1.3 MB 17.1 MB/s eta 0:00:00
# Collecting ml-dtypes<1.0.0,>=0.5.1
#   Downloading ml_dtypes-0.5.1-cp310-cp310-win_amd64.whl (209 kB)
#      ------------------------------------- 209.7/209.7 kB 13.3 MB/s eta 0:00:00
# Collecting libclang>=13.0.0
#   Downloading libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
#      --------------------------------------- 26.4/26.4 MB 15.6 MB/s eta 0:00:00
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1
#   Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Requirement already satisfied: six>=1.12.0 in c:\users\punna\appdata\roaming\python\python310\site-packages (from tensorflow) (1.17.0)
# Collecting flatbuffers>=24.3.25
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Collecting absl-py>=1.0.0
#   Downloading absl_py-2.2.2-py3-none-any.whl (135 kB)
#      -------------------------------------- 135.6/135.6 kB 4.0 MB/s eta 0:00:00
# Collecting numpy<2.2.0,>=1.26.0
#   Downloading numpy-2.1.3-cp310-cp310-win_amd64.whl (12.9 MB)
#      --------------------------------------- 12.9/12.9 MB 32.8 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in c:\users\punna\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (65.5.0)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3
#   Downloading protobuf-5.29.4-cp310-abi3-win_amd64.whl (434 kB)
#      -------------------------------------- 434.5/434.5 kB 5.4 MB/s eta 0:00:00
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
#      ---------------------------------------- 71.9/71.9 kB 3.9 MB/s eta 0:00:00
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ---------------------------------------- 57.5/57.5 kB ? eta 0:00:00
# Collecting tensorboard~=2.19.0
#   Downloading tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
#      ---------------------------------------- 5.5/5.5 MB 23.5 MB/s eta 0:00:00
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.31.0-cp310-cp310-win_amd64.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 18.7 MB/s eta 0:00:00
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-3.0.1-py3-none-any.whl (7.2 kB)
# Collecting requests<3,>=2.21.0
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ---------------------------------------- 64.9/64.9 kB 3.4 MB/s eta 0:00:00
# Collecting h5py>=3.11.0
#   Downloading h5py-3.13.0-cp310-cp310-win_amd64.whl (3.0 MB)
#      ---------------------------------------- 3.0/3.0 MB 11.1 MB/s eta 0:00:00
# Collecting wheel<1.0,>=0.23.0
#   Downloading wheel-0.45.1-py3-none-any.whl (72 kB)
#      ---------------------------------------- 72.5/72.5 kB 2.0 MB/s eta 0:00:00
# Collecting rich
#   Downloading rich-14.0.0-py3-none-any.whl (243 kB)
#      ------------------------------------- 243.2/243.2 kB 14.6 MB/s eta 0:00:00
# Collecting namex
#   Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Collecting optree
#   Downloading optree-0.15.0-cp310-cp310-win_amd64.whl (297 kB)
#      -------------------------------------- 297.3/297.3 kB 6.1 MB/s eta 0:00:00
# Collecting certifi>=2017.4.17
#   Downloading certifi-2025.1.31-py3-none-any.whl (166 kB)
#      -------------------------------------- 166.4/166.4 kB 5.0 MB/s eta 0:00:00
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.4.0-py3-none-any.whl (128 kB)
#      -------------------------------------- 128.7/128.7 kB 7.4 MB/s eta 0:00:00
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.4.1-cp310-cp310-win_amd64.whl (102 kB)
#      -------------------------------------- 102.8/102.8 kB 3.0 MB/s eta 0:00:00
# Collecting idna<4,>=2.5
#   Downloading idna-3.10-py3-none-any.whl (70 kB)
#      ---------------------------------------- 70.4/70.4 kB 1.9 MB/s eta 0:00:00
# Collecting markdown>=2.6.8
#   Downloading markdown-3.8-py3-none-any.whl (106 kB)
#      -------------------------------------- 106.2/106.2 kB 3.1 MB/s eta 0:00:00
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Collecting werkzeug>=1.0.1
#   Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
#      -------------------------------------- 224.5/224.5 kB 6.9 MB/s eta 0:00:00
# Collecting MarkupSafe>=2.1.1
#   Downloading MarkupSafe-3.0.2-cp310-cp310-win_amd64.whl (15 kB)
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      ---------------------------------------- 87.5/87.5 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\punna\appdata\roaming\python\python310\site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: namex, libclang, flatbuffers, wrapt, wheel, urllib3, termcolor, tensorflow-io-gcs-filesystem, tensorboard-data-server, protobuf, optree, opt-einsum, numpy, mdurl, MarkupSafe, markdown, idna, grpcio, google-pasta, gast, charset-normalizer, certifi, absl-py, werkzeug, requests, ml-dtypes, markdown-it-py, h5py, astunparse, tensorboard, rich, keras, tensorflow
# Successfully installed MarkupSafe-3.0.2 absl-py-2.2.2 astunparse-1.6.3 certifi-2025.1.31 charset-normalizer-3.4.1 flatbuffers-25.2.10 gast-0.6.0 google-pasta-0.2.0 grpcio-1.71.0 h5py-3.13.0 idna-3.10 keras-3.9.2 libclang-18.1.1 markdown-3.8 markdown-it-py-3.0.0 mdurl-0.1.2 ml-dtypes-0.5.1 namex-0.0.8 numpy-2.1.3 opt-einsum-3.4.0 optree-0.15.0 protobuf-5.29.4 requests-2.32.3 rich-14.0.0 tensorboard-2.19.0 tensorboard-data-server-0.7.2 tensorflow-2.19.0 tensorflow-io-gcs-filesystem-0.31.0 termcolor-3.0.1 urllib3-2.4.0 werkzeug-3.1.3 wheel-0.45.1 wrapt-1.17.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install pandas
# %pip install numpy
# %pip install matplotlib
# %pip install seaborn
# %pip install scikit-learn
# Out:
# Requirement already satisfied: pandas in c:\users\punna\appdata\local\programs\python\python310\lib\site-packages (2.2.3)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\punna\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\punna\appdata\roaming\python\python310\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\punna\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\punna\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\punna\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in c:\users\punna\appdata\local\programs\python\python310\lib\site-packages (2.1.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting matplotlib
#   Downloading matplotlib-3.10.1-cp310-cp310-win_amd64.whl (8.1 MB)
#      ---------------------------------------- 8.1/8.1 MB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in c:\users\punna\appdata\roaming\python\python310\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\punna\appdata\roaming\python\python310\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: numpy>=1.23 in c:\users\punna\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.1.3)
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.8-cp310-cp310-win_amd64.whl (71 kB)
#      ---------------------------------------- 71.9/71.9 kB ? eta 0:00:00
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
#      -------------------------------------- 111.1/111.1 kB 6.7 MB/s eta 0:00:00
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.57.0-cp310-cp310-win_amd64.whl (2.2 MB)
#      ---------------------------------------- 2.2/2.2 MB 8.2 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.1-cp310-cp310-win_amd64.whl (218 kB)
#      ------------------------------------- 218.6/218.6 kB 13.9 MB/s eta 0:00:00
# Collecting pillow>=8
#   Downloading pillow-11.2.1-cp310-cp310-win_amd64.whl (2.7 MB)
#      ---------------------------------------- 2.7/2.7 MB 10.0 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in c:\users\punna\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.1 cycler-0.12.1 fonttools-4.57.0 kiwisolver-1.4.8 matplotlib-3.10.1 pillow-11.2.1 pyparsing-3.2.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#      -------------------------------------- 294.9/294.9 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\punna\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (2.1.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\punna\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (3.10.1)
# Requirement already satisfied: pandas>=1.2 in c:\users\punna\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\punna\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\punna\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\punna\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\punna\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.57.0)
# Requirement already satisfied: pillow>=8 in c:\users\punna\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\punna\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\punna\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\punna\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: pytz>=2020.1 in c:\users\punna\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\punna\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\punna\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting scikit-learn
#   Downloading scikit_learn-1.6.1-cp310-cp310-win_amd64.whl (11.1 MB)
#      --------------------------------------- 11.1/11.1 MB 10.2 MB/s eta 0:00:00
# Collecting threadpoolctl>=3.1.0
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\punna\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (2.1.3)
# Collecting scipy>=1.6.0
#   Downloading scipy-1.15.2-cp310-cp310-win_amd64.whl (41.2 MB)
#      --------------------------------------- 41.2/41.2 MB 25.2 MB/s eta 0:00:00
# Collecting joblib>=1.2.0
#   Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#      -------------------------------------- 301.8/301.8 kB 9.4 MB/s eta 0:00:00
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.4.2 scikit-learn-1.6.1 scipy-1.15.2 threadpoolctl-3.6.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, roc_auc_score, precision_recall_curve
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Flatten, Dense, Dropout, BatchNormalization, ReLU

# Load the dataset
data = pd.read_csv('creditcard.csv')

# Separate features and target
X = data.drop(['Class'], axis=1)
y = data['Class']

# Scale the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Reshape input for Conv1D: (samples, timesteps, features)
X_scaled = np.expand_dims(X_scaled, axis=2)

# Split into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Build the 17-layer CNN model
model = Sequential([
    Conv1D(32, kernel_size=2, input_shape=(X_train.shape[1], 1)),
    ReLU(),
    BatchNormalization(),
    Dropout(0.2),
    Conv1D(64, kernel_size=2),
    ReLU(),
    BatchNormalization(),
    Dropout(0.5),
    Conv1D(64, kernel_size=2),
    ReLU(),
    BatchNormalization(),
    Dropout(0.25),
    Flatten(),
    Dense(100),
    ReLU(),
    Dropout(0.5),
    Dense(50),
    ReLU(),
    Dense(25),
    ReLU(),
    Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=2048, validation_data=(X_test, y_test), verbose=1)

# Evaluate the model
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
tn, fp, fn, tp = cm.ravel()

# Metrics
accuracy = (tp + tn) / (tp + tn + fp + fn)
precision = tp / (tp + fp) if (tp + fp) > 0 else 0
recall = tp / (tp + fn) if (tp + fn) > 0 else 0
auc = roc_auc_score(y_test, y_pred_prob)
prc_precision, prc_recall, _ = precision_recall_curve(y_test, y_pred_prob)

# Print Metrics
print("17-Layer Model Metrics:")
print(f"Training Accuracy: {history.history['accuracy'][-1]:.4f}")
print(f"Validation Accuracy: {history.history['val_accuracy'][-1]:.4f}")
print(f"Loss: {history.history['val_loss'][-1]:.4f}")
print(f"Confusion Matrix: {cm}")
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"AUC: {auc:.4f}")
print(f"Total Fraudulent Transactions in Test Set: {sum(y_test)}")

import matplotlib.pyplot as plt

# Extract accuracy values
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
epochs = range(1, len(train_acc) + 1)

# Plot
plt.figure(figsize=(10, 6))
plt.plot(epochs, train_acc, label='Training Accuracy', linestyle='-', color='blue')
plt.plot(epochs, val_acc, label='Validation Accuracy', linestyle=':', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training vs Validation Accuracy')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Epoch 1/100
# c:\Users\punna\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 8s 59ms/step - accuracy: 0.9882 - loss: 0.0638 - val_accuracy: 0.9986 - val_loss: 0.0072
# Epoch 2/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 62ms/step - accuracy: 0.9992 - loss: 0.0049 - val_accuracy: 0.9989 - val_loss: 0.0062
# Epoch 3/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 63ms/step - accuracy: 0.9992 - loss: 0.0038 - val_accuracy: 0.9992 - val_loss: 0.0047
# Epoch 4/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - accuracy: 0.9991 - loss: 0.0047 - val_accuracy: 0.9993 - val_loss: 0.0039
# Epoch 5/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9994 - loss: 0.0034 - val_accuracy: 0.9994 - val_loss: 0.0036
# Epoch 6/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9992 - loss: 0.0039 - val_accuracy: 0.9994 - val_loss: 0.0034
# Epoch 7/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 58ms/step - accuracy: 0.9992 - loss: 0.0039 - val_accuracy: 0.9994 - val_loss: 0.0029
# Epoch 8/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9994 - loss: 0.0030 - val_accuracy: 0.9993 - val_loss: 0.0029
# Epoch 9/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - accuracy: 0.9994 - loss: 0.0028 - val_accuracy: 0.9994 - val_loss: 0.0030
# Epoch 10/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9994 - loss: 0.0032 - val_accuracy: 0.9993 - val_loss: 0.0032
# Epoch 11/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9993 - loss: 0.0034 - val_accuracy: 0.9993 - val_loss: 0.0030
# Epoch 12/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 62ms/step - accuracy: 0.9993 - loss: 0.0034 - val_accuracy: 0.9994 - val_loss: 0.0029
# Epoch 13/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 62ms/step - accuracy: 0.9992 - loss: 0.0030 - val_accuracy: 0.9993 - val_loss: 0.0029
# Epoch 14/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 64ms/step - accuracy: 0.9994 - loss: 0.0030 - val_accuracy: 0.9994 - val_loss: 0.0032
# Epoch 15/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 62ms/step - accuracy: 0.9994 - loss: 0.0033 - val_accuracy: 0.9993 - val_loss: 0.0029
# Epoch 16/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 61ms/step - accuracy: 0.9993 - loss: 0.0031 - val_accuracy: 0.9993 - val_loss: 0.0027
# Epoch 17/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - accuracy: 0.9993 - loss: 0.0029 - val_accuracy: 0.9994 - val_loss: 0.0029
# Epoch 18/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 61ms/step - accuracy: 0.9995 - loss: 0.0024 - val_accuracy: 0.9994 - val_loss: 0.0029
# Epoch 19/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 61ms/step - accuracy: 0.9994 - loss: 0.0025 - val_accuracy: 0.9994 - val_loss: 0.0028
# Epoch 20/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 62ms/step - accuracy: 0.9994 - loss: 0.0028 - val_accuracy: 0.9994 - val_loss: 0.0028
# Epoch 21/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - accuracy: 0.9994 - loss: 0.0028 - val_accuracy: 0.9994 - val_loss: 0.0028
# Epoch 22/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - accuracy: 0.9994 - loss: 0.0025 - val_accuracy: 0.9994 - val_loss: 0.0028
# Epoch 23/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - accuracy: 0.9993 - loss: 0.0028 - val_accuracy: 0.9993 - val_loss: 0.0029
# Epoch 24/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9995 - loss: 0.0020 - val_accuracy: 0.9994 - val_loss: 0.0029
# Epoch 25/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9994 - loss: 0.0024 - val_accuracy: 0.9994 - val_loss: 0.0027
# Epoch 26/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9994 - loss: 0.0021 - val_accuracy: 0.9994 - val_loss: 0.0028
# Epoch 27/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9995 - loss: 0.0021 - val_accuracy: 0.9993 - val_loss: 0.0029
# Epoch 28/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9994 - loss: 0.0024 - val_accuracy: 0.9993 - val_loss: 0.0028
# Epoch 29/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 58ms/step - accuracy: 0.9994 - loss: 0.0024 - val_accuracy: 0.9994 - val_loss: 0.0028
# Epoch 30/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - accuracy: 0.9994 - loss: 0.0022 - val_accuracy: 0.9994 - val_loss: 0.0029
# Epoch 31/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9994 - loss: 0.0024 - val_accuracy: 0.9994 - val_loss: 0.0028
# Epoch 32/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9995 - loss: 0.0020 - val_accuracy: 0.9993 - val_loss: 0.0030
# Epoch 33/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 58ms/step - accuracy: 0.9994 - loss: 0.0021 - val_accuracy: 0.9994 - val_loss: 0.0031
# Epoch 34/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9995 - loss: 0.0018 - val_accuracy: 0.9993 - val_loss: 0.0030
# Epoch 35/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9994 - loss: 0.0021 - val_accuracy: 0.9994 - val_loss: 0.0030
# Epoch 36/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9994 - loss: 0.0020 - val_accuracy: 0.9994 - val_loss: 0.0031
# Epoch 37/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9994 - loss: 0.0020 - val_accuracy: 0.9994 - val_loss: 0.0029
# Epoch 38/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9994 - loss: 0.0022 - val_accuracy: 0.9994 - val_loss: 0.0030
# Epoch 39/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9993 - loss: 0.0023 - val_accuracy: 0.9994 - val_loss: 0.0034
# Epoch 40/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9995 - loss: 0.0019 - val_accuracy: 0.9994 - val_loss: 0.0030
# Epoch 41/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9994 - loss: 0.0024 - val_accuracy: 0.9994 - val_loss: 0.0030
# Epoch 42/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9995 - loss: 0.0018 - val_accuracy: 0.9994 - val_loss: 0.0030
# Epoch 43/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9995 - loss: 0.0019 - val_accuracy: 0.9994 - val_loss: 0.0031
# Epoch 44/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9994 - loss: 0.0020 - val_accuracy: 0.9993 - val_loss: 0.0031
# Epoch 45/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9995 - loss: 0.0016 - val_accuracy: 0.9993 - val_loss: 0.0033
# Epoch 46/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9994 - loss: 0.0019 - val_accuracy: 0.9994 - val_loss: 0.0031
# Epoch 47/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9994 - loss: 0.0020 - val_accuracy: 0.9994 - val_loss: 0.0031
# Epoch 48/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9995 - loss: 0.0020 - val_accuracy: 0.9994 - val_loss: 0.0031
# Epoch 49/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9994 - loss: 0.0020 - val_accuracy: 0.9994 - val_loss: 0.0032
# Epoch 50/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9994 - loss: 0.0019 - val_accuracy: 0.9994 - val_loss: 0.0032
# Epoch 51/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9995 - loss: 0.0018 - val_accuracy: 0.9994 - val_loss: 0.0033
# Epoch 52/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9994 - loss: 0.0017 - val_accuracy: 0.9994 - val_loss: 0.0033
# Epoch 53/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9995 - loss: 0.0015 - val_accuracy: 0.9995 - val_loss: 0.0031
# Epoch 54/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9995 - loss: 0.0016 - val_accuracy: 0.9994 - val_loss: 0.0032
# Epoch 55/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9994 - loss: 0.0021 - val_accuracy: 0.9994 - val_loss: 0.0031
# Epoch 56/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9995 - loss: 0.0019 - val_accuracy: 0.9995 - val_loss: 0.0034
# Epoch 57/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9995 - loss: 0.0018 - val_accuracy: 0.9995 - val_loss: 0.0035
# Epoch 58/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9995 - loss: 0.0015 - val_accuracy: 0.9994 - val_loss: 0.0031
# Epoch 59/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - accuracy: 0.9995 - loss: 0.0017 - val_accuracy: 0.9994 - val_loss: 0.0035
# Epoch 60/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - accuracy: 0.9996 - loss: 0.0014 - val_accuracy: 0.9995 - val_loss: 0.0031
# Epoch 61/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - accuracy: 0.9995 - loss: 0.0017 - val_accuracy: 0.9995 - val_loss: 0.0034
# Epoch 62/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - accuracy: 0.9995 - loss: 0.0014 - val_accuracy: 0.9995 - val_loss: 0.0033
# Epoch 63/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 61ms/step - accuracy: 0.9994 - loss: 0.0016 - val_accuracy: 0.9995 - val_loss: 0.0034
# Epoch 64/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - accuracy: 0.9996 - loss: 0.0013 - val_accuracy: 0.9995 - val_loss: 0.0034
# Epoch 65/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - accuracy: 0.9996 - loss: 0.0014 - val_accuracy: 0.9995 - val_loss: 0.0032
# Epoch 66/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - accuracy: 0.9996 - loss: 0.0015 - val_accuracy: 0.9994 - val_loss: 0.0033
# Epoch 67/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - accuracy: 0.9995 - loss: 0.0018 - val_accuracy: 0.9995 - val_loss: 0.0033
# Epoch 68/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - accuracy: 0.9996 - loss: 0.0013 - val_accuracy: 0.9994 - val_loss: 0.0037
# Epoch 69/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - accuracy: 0.9996 - loss: 0.0013 - val_accuracy: 0.9995 - val_loss: 0.0035
# Epoch 70/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - accuracy: 0.9995 - loss: 0.0016 - val_accuracy: 0.9994 - val_loss: 0.0035
# Epoch 71/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - accuracy: 0.9995 - loss: 0.0015 - val_accuracy: 0.9994 - val_loss: 0.0034
# Epoch 72/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - accuracy: 0.9996 - loss: 0.0014 - val_accuracy: 0.9994 - val_loss: 0.0036
# Epoch 73/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 61ms/step - accuracy: 0.9996 - loss: 0.0013 - val_accuracy: 0.9995 - val_loss: 0.0038
# Epoch 74/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 61ms/step - accuracy: 0.9995 - loss: 0.0012 - val_accuracy: 0.9995 - val_loss: 0.0037
# Epoch 75/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - accuracy: 0.9995 - loss: 0.0017 - val_accuracy: 0.9995 - val_loss: 0.0037
# Epoch 76/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 61ms/step - accuracy: 0.9996 - loss: 0.0014 - val_accuracy: 0.9995 - val_loss: 0.0037
# Epoch 77/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 61ms/step - accuracy: 0.9996 - loss: 0.0015 - val_accuracy: 0.9995 - val_loss: 0.0035
# Epoch 78/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - accuracy: 0.9996 - loss: 0.0013 - val_accuracy: 0.9994 - val_loss: 0.0039
# Epoch 79/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 61ms/step - accuracy: 0.9995 - loss: 0.0013 - val_accuracy: 0.9994 - val_loss: 0.0043
# Epoch 80/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 61ms/step - accuracy: 0.9995 - loss: 0.0015 - val_accuracy: 0.9994 - val_loss: 0.0040
# Epoch 81/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - accuracy: 0.9996 - loss: 0.0015 - val_accuracy: 0.9994 - val_loss: 0.0039
# Epoch 82/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 61ms/step - accuracy: 0.9995 - loss: 0.0013 - val_accuracy: 0.9994 - val_loss: 0.0042
# Epoch 83/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - accuracy: 0.9995 - loss: 0.0013 - val_accuracy: 0.9995 - val_loss: 0.0041
# Epoch 84/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - accuracy: 0.9995 - loss: 0.0013 - val_accuracy: 0.9994 - val_loss: 0.0037
# Epoch 85/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 61ms/step - accuracy: 0.9996 - loss: 0.0012 - val_accuracy: 0.9994 - val_loss: 0.0040
# Epoch 86/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 61ms/step - accuracy: 0.9995 - loss: 0.0015 - val_accuracy: 0.9995 - val_loss: 0.0039
# Epoch 87/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 61ms/step - accuracy: 0.9995 - loss: 0.0015 - val_accuracy: 0.9995 - val_loss: 0.0045
# Epoch 88/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - accuracy: 0.9996 - loss: 0.0011 - val_accuracy: 0.9994 - val_loss: 0.0039
# Epoch 89/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 61ms/step - accuracy: 0.9995 - loss: 0.0015 - val_accuracy: 0.9994 - val_loss: 0.0042
# Epoch 90/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - accuracy: 0.9996 - loss: 0.0013 - val_accuracy: 0.9995 - val_loss: 0.0039
# Epoch 91/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 61ms/step - accuracy: 0.9996 - loss: 0.0012 - val_accuracy: 0.9994 - val_loss: 0.0041
# Epoch 92/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - accuracy: 0.9996 - loss: 0.0013 - val_accuracy: 0.9995 - val_loss: 0.0042
# Epoch 93/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - accuracy: 0.9997 - loss: 0.0010 - val_accuracy: 0.9994 - val_loss: 0.0044
# Epoch 94/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 63ms/step - accuracy: 0.9996 - loss: 9.8737e-04 - val_accuracy: 0.9995 - val_loss: 0.0045
# Epoch 95/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 63ms/step - accuracy: 0.9995 - loss: 0.0014 - val_accuracy: 0.9995 - val_loss: 0.0042
# Epoch 96/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 62ms/step - accuracy: 0.9995 - loss: 0.0013 - val_accuracy: 0.9995 - val_loss: 0.0048
# Epoch 97/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - accuracy: 0.9996 - loss: 0.0011 - val_accuracy: 0.9994 - val_loss: 0.0050
# Epoch 98/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 61ms/step - accuracy: 0.9996 - loss: 0.0012 - val_accuracy: 0.9995 - val_loss: 0.0045
# Epoch 99/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 61ms/step - accuracy: 0.9997 - loss: 0.0011 - val_accuracy: 0.9994 - val_loss: 0.0044
# Epoch 100/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - accuracy: 0.9996 - loss: 0.0012 - val_accuracy: 0.9995 - val_loss: 0.0045
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step
# 17-Layer Model Metrics:
# Training Accuracy: 0.9996
# Validation Accuracy: 0.9995
# Loss: 0.0045
# Confusion Matrix: [[56858     6]
#  [   24    74]]
# Accuracy: 0.9995
# Precision: 0.9250
# Recall: 0.7551
# AUC: 0.9769
# Total Fraudulent Transactions in Test Set: 98

# %%
# plot the graph between the training accuracy and validation accuracy for file where on x axis consists number of epochs  and y axis contains accuracy

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 import matplotlib.pyplot as plt
#       3 # Extract training and validation accuracy from the history object
# ----> 4 training_accuracy = history.history['accuracy']
#       5 validation_accuracy = history.history['val_accuracy']
#       6 epochs = range(1, len(training_accuracy) + 1)
#
# NameError: name 'history' is not defined
